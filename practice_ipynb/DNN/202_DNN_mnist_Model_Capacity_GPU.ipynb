# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 2분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 4s 4ms/step - loss: 0.3229 - accuracy: 0.9084 - val_loss: 0.1783 - val_accuracy: 0.9488
# Epoch 2/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1472 - accuracy: 0.9575 - val_loss: 0.1278 - val_accuracy: 0.9619
# Epoch 3/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1009 - accuracy: 0.9710 - val_loss: 0.1066 - val_accuracy: 0.9688
# Epoch 4/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0749 - accuracy: 0.9781 - val_loss: 0.0966 - val_accuracy: 0.9710
# Epoch 5/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0579 - accuracy: 0.9831 - val_loss: 0.0912 - val_accuracy: 0.9739
# Epoch 6/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0465 - accuracy: 0.9865 - val_loss: 0.0858 - val_accuracy: 0.9757
# Epoch 7/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 0.9893 - val_loss: 0.0835 - val_accuracy: 0.9766
# Epoch 8/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0302 - accuracy: 0.9914 - val_loss: 0.0864 - val_accuracy: 0.9768
# Epoch 9/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0242 - accuracy: 0.9936 - val_loss: 0.0907 - val_accuracy: 0.9763
# Epoch 10/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.0873 - val_accuracy: 0.9760
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0157 - accuracy: 0.9959 - val_loss: 0.0901 - val_accuracy: 0.9778
# Epoch 12/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0122 - accuracy: 0.9970 - val_loss: 0.1013 - val_accuracy: 0.9752
# Epoch 13/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0924 - val_accuracy: 0.9756
# Epoch 14/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.1053 - val_accuracy: 0.9754
# Epoch 15/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 0.1035 - val_accuracy: 0.9757
# Epoch 16/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.1028 - val_accuracy: 0.9780
# Epoch 17/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.1030 - val_accuracy: 0.9769
# Epoch 18/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.1029 - val_accuracy: 0.9778
# Epoch 19/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1097 - val_accuracy: 0.9771
# Epoch 20/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1144 - val_accuracy: 0.9770
# Epoch 21/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1178 - val_accuracy: 0.9775
# Epoch 22/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1182 - val_accuracy: 0.9772
# Epoch 23/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1177 - val_accuracy: 0.9787
# Epoch 24/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.3507e-04 - accuracy: 0.9998 - val_loss: 0.1361 - val_accuracy: 0.9768
# Epoch 25/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.4396e-04 - accuracy: 0.9999 - val_loss: 0.1238 - val_accuracy: 0.9794
# Epoch 26/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.1386e-04 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9787
# Epoch 27/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.9057e-04 - accuracy: 0.9998 - val_loss: 0.1393 - val_accuracy: 0.9780
# Epoch 28/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.3082e-04 - accuracy: 0.9999 - val_loss: 0.1333 - val_accuracy: 0.9791
# Epoch 29/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.5398e-04 - accuracy: 0.9999 - val_loss: 0.1389 - val_accuracy: 0.9783
# Epoch 30/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.5303e-04 - accuracy: 0.9999 - val_loss: 0.1483 - val_accuracy: 0.9769
# Epoch 31/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.6378e-04 - accuracy: 0.9999 - val_loss: 0.1403 - val_accuracy: 0.9798
# Epoch 32/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.7828e-04 - accuracy: 1.0000 - val_loss: 0.1473 - val_accuracy: 0.9789
# Epoch 33/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.2438e-04 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 0.9770
# Epoch 34/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5717e-04 - accuracy: 0.9999 - val_loss: 0.1615 - val_accuracy: 0.9783
# Epoch 35/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6622e-04 - accuracy: 0.9999 - val_loss: 0.1596 - val_accuracy: 0.9786
# Epoch 36/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.1282e-05 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 0.9793
# Epoch 37/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.5141e-05 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 0.9787
# Epoch 38/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.3820e-05 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9788
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2721e-05 - accuracy: 1.0000 - val_loss: 0.1756 - val_accuracy: 0.9783
# Epoch 40/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.5010e-05 - accuracy: 1.0000 - val_loss: 0.1751 - val_accuracy: 0.9787
# Epoch 41/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.8292e-05 - accuracy: 1.0000 - val_loss: 0.1807 - val_accuracy: 0.9786
# Epoch 42/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.8109e-05 - accuracy: 1.0000 - val_loss: 0.1697 - val_accuracy: 0.9789
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.1531e-06 - accuracy: 1.0000 - val_loss: 0.1736 - val_accuracy: 0.9789
# Epoch 44/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.1358e-06 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 0.9793
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.8836e-06 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9787
# Epoch 46/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.8439e-06 - accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9794
# Epoch 47/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.2221e-06 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9800
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0152e-06 - accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9795
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.3451e-07 - accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9797
# Epoch 50/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6731e-06 - accuracy: 1.0000 - val_loss: 0.1907 - val_accuracy: 0.9797
# Epoch 51/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6753e-07 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9794
# Epoch 52/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.3195e-08 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9794
# Epoch 53/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.4217e-08 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9794
# Epoch 54/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.7314e-08 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9797
# Epoch 55/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.0740e-08 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9795
# Epoch 56/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.5134e-08 - accuracy: 1.0000 - val_loss: 0.1969 - val_accuracy: 0.9797
# Epoch 57/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.5082e-08 - accuracy: 1.0000 - val_loss: 0.1976 - val_accuracy: 0.9796
# Epoch 58/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.9594e-08 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9794
# Epoch 59/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.7515e-08 - accuracy: 1.0000 - val_loss: 0.1995 - val_accuracy: 0.9797
# Epoch 60/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.5193e-08 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9795
# Epoch 61/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.3606e-08 - accuracy: 1.0000 - val_loss: 0.2008 - val_accuracy: 0.9790
# Epoch 62/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2054e-08 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9795
# Epoch 63/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.1122e-08 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9794
# Epoch 64/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.9891e-08 - accuracy: 1.0000 - val_loss: 0.2020 - val_accuracy: 0.9794
# Epoch 65/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.9091e-08 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9797
# Epoch 66/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.8177e-08 - accuracy: 1.0000 - val_loss: 0.2029 - val_accuracy: 0.9793
# Epoch 67/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.7238e-08 - accuracy: 1.0000 - val_loss: 0.2034 - val_accuracy: 0.9797
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6443e-08 - accuracy: 1.0000 - val_loss: 0.2037 - val_accuracy: 0.9795
# Epoch 69/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5842e-08 - accuracy: 1.0000 - val_loss: 0.2040 - val_accuracy: 0.9796
# Epoch 70/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.5187e-08 - accuracy: 1.0000 - val_loss: 0.2042 - val_accuracy: 0.9798
# Epoch 71/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.4678e-08 - accuracy: 1.0000 - val_loss: 0.2041 - val_accuracy: 0.9796
# Epoch 72/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.4029e-08 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9796
# Epoch 73/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.3548e-08 - accuracy: 1.0000 - val_loss: 0.2051 - val_accuracy: 0.9796
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3123e-08 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9795
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2758e-08 - accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9796
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2440e-08 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9795
# Epoch 77/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.2028e-08 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9795
# Epoch 78/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1675e-08 - accuracy: 1.0000 - val_loss: 0.2067 - val_accuracy: 0.9797
# Epoch 79/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1345e-08 - accuracy: 1.0000 - val_loss: 0.2074 - val_accuracy: 0.9795
# Epoch 80/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.1121e-08 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9795
# Epoch 81/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0873e-08 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9797
# Epoch 82/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0490e-08 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9796
# Epoch 83/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0314e-08 - accuracy: 1.0000 - val_loss: 0.2091 - val_accuracy: 0.9795
# Epoch 84/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0043e-08 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9795
# Epoch 85/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.8050e-09 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9796
# Epoch 86/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.6063e-09 - accuracy: 1.0000 - val_loss: 0.2093 - val_accuracy: 0.9796
# Epoch 87/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.4001e-09 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9795
# Epoch 88/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.1493e-09 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9796
# Epoch 89/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.0053e-09 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9794
# Epoch 90/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.9183e-09 - accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.9795
# Epoch 91/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.6402e-09 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9796
# Epoch 92/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.5160e-09 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9794
# Epoch 93/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.3819e-09 - accuracy: 1.0000 - val_loss: 0.2113 - val_accuracy: 0.9793
# Epoch 94/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.2254e-09 - accuracy: 1.0000 - val_loss: 0.2118 - val_accuracy: 0.9794
# Epoch 95/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.1385e-09 - accuracy: 1.0000 - val_loss: 0.2119 - val_accuracy: 0.9796
# Epoch 96/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.9771e-09 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9796
# Epoch 97/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.9001e-09 - accuracy: 1.0000 - val_loss: 0.2124 - val_accuracy: 0.9797
# Epoch 98/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.6691e-09 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9794
# Epoch 99/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.6517e-09 - accuracy: 1.0000 - val_loss: 0.2133 - val_accuracy: 0.9796
# Epoch 100/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.5077e-09 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9794
# CPU times: user 2min 31s, sys: 22.6 s, total: 2min 53s
# Wall time: 2min 28s

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1723 - accuracy: 0.9806
# Loss = 0.17230
# Accuracy = 0.98060

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
