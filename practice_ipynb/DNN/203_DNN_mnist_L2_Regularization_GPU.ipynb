# %% [markdown]
# # MNIST - Categorical Classification
# > # L2 Regularization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - L2 Regularization 적용

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001),
                       input_shape=(28 * 28,)))
mnist.add(layers.Dense(256, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 6ms/step - loss: 0.2658 - accuracy: 0.9218 - val_loss: 0.1346 - val_accuracy: 0.9609
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1027 - accuracy: 0.9718 - val_loss: 0.1122 - val_accuracy: 0.9703
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0713 - accuracy: 0.9811 - val_loss: 0.0937 - val_accuracy: 0.9768
# Epoch 4/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0550 - accuracy: 0.9861 - val_loss: 0.1065 - val_accuracy: 0.9734
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0434 - accuracy: 0.9894 - val_loss: 0.0922 - val_accuracy: 0.9793
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0369 - accuracy: 0.9920 - val_loss: 0.0917 - val_accuracy: 0.9785
# Epoch 7/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0332 - accuracy: 0.9932 - val_loss: 0.0977 - val_accuracy: 0.9797
# Epoch 8/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0302 - accuracy: 0.9940 - val_loss: 0.1102 - val_accuracy: 0.9778
# Epoch 9/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0267 - accuracy: 0.9947 - val_loss: 0.1042 - val_accuracy: 0.9793
# Epoch 10/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0243 - accuracy: 0.9953 - val_loss: 0.1190 - val_accuracy: 0.9767
# Epoch 11/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0258 - accuracy: 0.9951 - val_loss: 0.1109 - val_accuracy: 0.9792
# Epoch 12/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0229 - accuracy: 0.9962 - val_loss: 0.1691 - val_accuracy: 0.9683
# Epoch 13/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0216 - accuracy: 0.9961 - val_loss: 0.1134 - val_accuracy: 0.9790
# Epoch 14/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0226 - accuracy: 0.9958 - val_loss: 0.1041 - val_accuracy: 0.9817
# Epoch 15/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0213 - accuracy: 0.9964 - val_loss: 0.1284 - val_accuracy: 0.9758
# Epoch 16/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0196 - accuracy: 0.9968 - val_loss: 0.1182 - val_accuracy: 0.9800
# Epoch 17/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0201 - accuracy: 0.9963 - val_loss: 0.1187 - val_accuracy: 0.9800
# Epoch 18/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0185 - accuracy: 0.9970 - val_loss: 0.1265 - val_accuracy: 0.9783
# Epoch 19/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0189 - accuracy: 0.9969 - val_loss: 0.1168 - val_accuracy: 0.9803
# Epoch 20/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0184 - accuracy: 0.9968 - val_loss: 0.1176 - val_accuracy: 0.9796
# Epoch 21/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0183 - accuracy: 0.9971 - val_loss: 0.1160 - val_accuracy: 0.9803
# Epoch 22/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0175 - accuracy: 0.9968 - val_loss: 0.1310 - val_accuracy: 0.9769
# Epoch 23/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0156 - accuracy: 0.9976 - val_loss: 0.1512 - val_accuracy: 0.9753
# Epoch 24/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0170 - accuracy: 0.9971 - val_loss: 0.1365 - val_accuracy: 0.9783
# Epoch 25/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0167 - accuracy: 0.9969 - val_loss: 0.1145 - val_accuracy: 0.9801
# Epoch 26/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0166 - accuracy: 0.9972 - val_loss: 0.1332 - val_accuracy: 0.9778
# Epoch 27/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0150 - accuracy: 0.9978 - val_loss: 0.1259 - val_accuracy: 0.9795
# Epoch 28/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0163 - accuracy: 0.9974 - val_loss: 0.1336 - val_accuracy: 0.9777
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9978 - val_loss: 0.1440 - val_accuracy: 0.9767
# Epoch 30/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9977 - val_loss: 0.1267 - val_accuracy: 0.9793
# Epoch 31/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9975 - val_loss: 0.1213 - val_accuracy: 0.9814
# Epoch 32/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.1268 - val_accuracy: 0.9786
# Epoch 33/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.1253 - val_accuracy: 0.9781
# Epoch 34/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9972 - val_loss: 0.1252 - val_accuracy: 0.9797
# Epoch 35/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0147 - accuracy: 0.9973 - val_loss: 0.1241 - val_accuracy: 0.9792
# Epoch 36/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0153 - accuracy: 0.9972 - val_loss: 0.1264 - val_accuracy: 0.9780
# Epoch 37/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0150 - accuracy: 0.9973 - val_loss: 0.1432 - val_accuracy: 0.9770
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 0.1349 - val_accuracy: 0.9755
# Epoch 39/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.1220 - val_accuracy: 0.9797
# Epoch 40/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 0.1235 - val_accuracy: 0.9778
# Epoch 41/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0139 - accuracy: 0.9975 - val_loss: 0.1493 - val_accuracy: 0.9757
# Epoch 42/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0138 - accuracy: 0.9977 - val_loss: 0.1276 - val_accuracy: 0.9793
# Epoch 43/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0137 - accuracy: 0.9976 - val_loss: 0.1380 - val_accuracy: 0.9793
# Epoch 44/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0134 - accuracy: 0.9981 - val_loss: 0.1275 - val_accuracy: 0.9806
# Epoch 45/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.1335 - val_accuracy: 0.9789
# Epoch 46/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.1535 - val_accuracy: 0.9767
# Epoch 47/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0119 - accuracy: 0.9979 - val_loss: 0.1603 - val_accuracy: 0.9754
# Epoch 48/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9980 - val_loss: 0.1327 - val_accuracy: 0.9784
# Epoch 49/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0132 - accuracy: 0.9981 - val_loss: 0.1271 - val_accuracy: 0.9789
# Epoch 50/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0130 - accuracy: 0.9979 - val_loss: 0.1411 - val_accuracy: 0.9791
# Epoch 51/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0119 - accuracy: 0.9981 - val_loss: 0.1428 - val_accuracy: 0.9797
# Epoch 52/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.1521 - val_accuracy: 0.9780
# Epoch 53/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9981 - val_loss: 0.1267 - val_accuracy: 0.9786
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9978 - val_loss: 0.1304 - val_accuracy: 0.9797
# Epoch 55/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9981 - val_loss: 0.1361 - val_accuracy: 0.9790
# Epoch 56/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9982 - val_loss: 0.1507 - val_accuracy: 0.9790
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.1578 - val_accuracy: 0.9767
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9983 - val_loss: 0.1441 - val_accuracy: 0.9790
# Epoch 59/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0116 - accuracy: 0.9982 - val_loss: 0.1398 - val_accuracy: 0.9770
# Epoch 60/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 0.1465 - val_accuracy: 0.9772
# Epoch 61/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0130 - accuracy: 0.9976 - val_loss: 0.1440 - val_accuracy: 0.9792
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.1467 - val_accuracy: 0.9787
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0115 - accuracy: 0.9980 - val_loss: 0.1469 - val_accuracy: 0.9774
# Epoch 64/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9979 - val_loss: 0.1388 - val_accuracy: 0.9778
# Epoch 65/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9981 - val_loss: 0.1459 - val_accuracy: 0.9772
# Epoch 66/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.1418 - val_accuracy: 0.9783
# Epoch 67/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9982 - val_loss: 0.1383 - val_accuracy: 0.9787
# Epoch 68/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9981 - val_loss: 0.1394 - val_accuracy: 0.9789
# Epoch 69/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 0.1628 - val_accuracy: 0.9750
# Epoch 70/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 0.1820 - val_accuracy: 0.9738
# Epoch 71/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.1547 - val_accuracy: 0.9771
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.1818 - val_accuracy: 0.9750
# Epoch 73/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9978 - val_loss: 0.1621 - val_accuracy: 0.9774
# Epoch 74/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0117 - accuracy: 0.9980 - val_loss: 0.1571 - val_accuracy: 0.9787
# Epoch 75/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0119 - accuracy: 0.9977 - val_loss: 0.1661 - val_accuracy: 0.9766
# Epoch 76/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.1488 - val_accuracy: 0.9790
# Epoch 77/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.1511 - val_accuracy: 0.9800
# Epoch 78/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.1592 - val_accuracy: 0.9787
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9981 - val_loss: 0.1730 - val_accuracy: 0.9773
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9981 - val_loss: 0.1533 - val_accuracy: 0.9783
# Epoch 81/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.1537 - val_accuracy: 0.9775
# Epoch 82/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.1354 - val_accuracy: 0.9785
# Epoch 83/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.1592 - val_accuracy: 0.9771
# Epoch 84/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0109 - accuracy: 0.9981 - val_loss: 0.1472 - val_accuracy: 0.9779
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0111 - accuracy: 0.9980 - val_loss: 0.1558 - val_accuracy: 0.9777
# Epoch 86/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9980 - val_loss: 0.1517 - val_accuracy: 0.9772
# Epoch 87/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0104 - accuracy: 0.9983 - val_loss: 0.1595 - val_accuracy: 0.9792
# Epoch 88/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 0.1692 - val_accuracy: 0.9776
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9981 - val_loss: 0.1476 - val_accuracy: 0.9788
# Epoch 90/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9983 - val_loss: 0.1589 - val_accuracy: 0.9778
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0108 - accuracy: 0.9984 - val_loss: 0.1526 - val_accuracy: 0.9790
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9982 - val_loss: 0.2173 - val_accuracy: 0.9667
# Epoch 93/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 0.1571 - val_accuracy: 0.9784
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0103 - accuracy: 0.9984 - val_loss: 0.1497 - val_accuracy: 0.9785
# Epoch 95/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0112 - accuracy: 0.9983 - val_loss: 0.1603 - val_accuracy: 0.9783
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0101 - accuracy: 0.9982 - val_loss: 0.1423 - val_accuracy: 0.9793
# Epoch 97/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9983 - val_loss: 0.1888 - val_accuracy: 0.9758
# Epoch 98/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0112 - accuracy: 0.9982 - val_loss: 0.1510 - val_accuracy: 0.9800
# Epoch 99/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.1536 - val_accuracy: 0.9764
# Epoch 100/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0100 - accuracy: 0.9982 - val_loss: 0.1451 - val_accuracy: 0.9790
# CPU times: user 3min 20s, sys: 27.5 s, total: 3min 48s
# Wall time: 3min 22s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1138 - accuracy: 0.9810
# Loss = 0.11380
# Accuracy = 0.98100

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
