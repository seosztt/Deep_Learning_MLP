# %% [markdown]
# # MNIST - Categorical Classification
# > # Batch Normalization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  * 활성화 함수의 입력값을 정규화 과정을 수행하여 전달
#  * Gradient Vanishing 문제 해결 및 더 큰 Learning Rate를 사용 가능

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, input_shape=(28 * 28,)))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(256))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 538,890
# Trainable params: 537,354
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 4ms/step - loss: 0.1810 - accuracy: 0.9456 - val_loss: 0.1065 - val_accuracy: 0.9682
# Epoch 2/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0750 - accuracy: 0.9776 - val_loss: 0.0949 - val_accuracy: 0.9726
# Epoch 3/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0462 - accuracy: 0.9854 - val_loss: 0.1041 - val_accuracy: 0.9706
# Epoch 4/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0915 - val_accuracy: 0.9747
# Epoch 5/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0890 - val_accuracy: 0.9769
# Epoch 6/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0172 - accuracy: 0.9941 - val_loss: 0.1115 - val_accuracy: 0.9726
# Epoch 7/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 0.0870 - val_accuracy: 0.9779
# Epoch 8/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.1000 - val_accuracy: 0.9782
# Epoch 9/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 0.0971 - val_accuracy: 0.9796
# Epoch 10/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.0949 - val_accuracy: 0.9800
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.1066 - val_accuracy: 0.9797
# Epoch 12/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1020 - val_accuracy: 0.9816
# Epoch 13/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.1093 - val_accuracy: 0.9779
# Epoch 14/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1151 - val_accuracy: 0.9781
# Epoch 15/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.1097 - val_accuracy: 0.9802
# Epoch 16/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.1045 - val_accuracy: 0.9812
# Epoch 17/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.1161 - val_accuracy: 0.9802
# Epoch 18/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.1157 - val_accuracy: 0.9797
# Epoch 19/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.1112 - val_accuracy: 0.9808
# Epoch 20/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1345 - val_accuracy: 0.9799
# Epoch 21/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.1166 - val_accuracy: 0.9817
# Epoch 22/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.1259 - val_accuracy: 0.9807
# Epoch 23/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.1138 - val_accuracy: 0.9822
# Epoch 24/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1227 - val_accuracy: 0.9794
# Epoch 25/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.1372 - val_accuracy: 0.9790
# Epoch 26/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.1345 - val_accuracy: 0.9805
# Epoch 27/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1282 - val_accuracy: 0.9797
# Epoch 28/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.1205 - val_accuracy: 0.9816
# Epoch 29/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.1407 - val_accuracy: 0.9799
# Epoch 30/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1319 - val_accuracy: 0.9812
# Epoch 31/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.1185 - val_accuracy: 0.9804
# Epoch 32/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1372 - val_accuracy: 0.9793
# Epoch 33/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.1325 - val_accuracy: 0.9807
# Epoch 34/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.1337 - val_accuracy: 0.9807
# Epoch 35/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.1274 - val_accuracy: 0.9805
# Epoch 36/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1549 - val_accuracy: 0.9800
# Epoch 37/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1364 - val_accuracy: 0.9808
# Epoch 38/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1510 - val_accuracy: 0.9808
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1443 - val_accuracy: 0.9797
# Epoch 40/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1399 - val_accuracy: 0.9817
# Epoch 41/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.1472 - val_accuracy: 0.9797
# Epoch 42/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.1608 - val_accuracy: 0.9777
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1513 - val_accuracy: 0.9804
# Epoch 44/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1523 - val_accuracy: 0.9793
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1549 - val_accuracy: 0.9812
# Epoch 46/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1614 - val_accuracy: 0.9803
# Epoch 47/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1540 - val_accuracy: 0.9813
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1918 - val_accuracy: 0.9778
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1891 - val_accuracy: 0.9787
# Epoch 50/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1669 - val_accuracy: 0.9794
# Epoch 51/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.9454e-04 - accuracy: 0.9997 - val_loss: 0.1597 - val_accuracy: 0.9812
# Epoch 52/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.9119e-04 - accuracy: 0.9998 - val_loss: 0.1637 - val_accuracy: 0.9817
# Epoch 53/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1708 - val_accuracy: 0.9803
# Epoch 54/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1586 - val_accuracy: 0.9805
# Epoch 55/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1578 - val_accuracy: 0.9820
# Epoch 56/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1655 - val_accuracy: 0.9818
# Epoch 57/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.0070e-04 - accuracy: 0.9998 - val_loss: 0.1604 - val_accuracy: 0.9810
# Epoch 58/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.7564e-04 - accuracy: 0.9997 - val_loss: 0.1741 - val_accuracy: 0.9807
# Epoch 59/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1700 - val_accuracy: 0.9811
# Epoch 60/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.2693e-04 - accuracy: 0.9998 - val_loss: 0.1844 - val_accuracy: 0.9792
# Epoch 61/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.8691e-04 - accuracy: 0.9997 - val_loss: 0.1680 - val_accuracy: 0.9812
# Epoch 62/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1745 - val_accuracy: 0.9807
# Epoch 63/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.2545e-04 - accuracy: 0.9997 - val_loss: 0.1787 - val_accuracy: 0.9803
# Epoch 64/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.0078e-04 - accuracy: 0.9996 - val_loss: 0.1968 - val_accuracy: 0.9800
# Epoch 65/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.5276e-04 - accuracy: 0.9998 - val_loss: 0.1843 - val_accuracy: 0.9799
# Epoch 66/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.6620e-04 - accuracy: 0.9998 - val_loss: 0.1839 - val_accuracy: 0.9802
# Epoch 67/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.6848e-04 - accuracy: 0.9997 - val_loss: 0.1836 - val_accuracy: 0.9810
# Epoch 68/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.3091e-04 - accuracy: 0.9998 - val_loss: 0.1791 - val_accuracy: 0.9824
# Epoch 69/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.5591e-04 - accuracy: 0.9998 - val_loss: 0.1781 - val_accuracy: 0.9811
# Epoch 70/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.4670e-04 - accuracy: 0.9999 - val_loss: 0.1767 - val_accuracy: 0.9809
# Epoch 71/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.9648e-04 - accuracy: 0.9997 - val_loss: 0.1776 - val_accuracy: 0.9815
# Epoch 72/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.7068e-04 - accuracy: 0.9999 - val_loss: 0.1895 - val_accuracy: 0.9804
# Epoch 73/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.3341e-04 - accuracy: 0.9998 - val_loss: 0.1797 - val_accuracy: 0.9825
# Epoch 74/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.3093e-04 - accuracy: 0.9998 - val_loss: 0.1911 - val_accuracy: 0.9808
# Epoch 75/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.4416e-04 - accuracy: 0.9997 - val_loss: 0.1937 - val_accuracy: 0.9793
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1795 - val_accuracy: 0.9812
# Epoch 77/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.9493e-04 - accuracy: 0.9998 - val_loss: 0.1842 - val_accuracy: 0.9806
# Epoch 78/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.0784e-04 - accuracy: 0.9998 - val_loss: 0.1850 - val_accuracy: 0.9817
# Epoch 79/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.8204e-04 - accuracy: 0.9997 - val_loss: 0.1822 - val_accuracy: 0.9808
# Epoch 80/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.5425e-04 - accuracy: 0.9998 - val_loss: 0.1910 - val_accuracy: 0.9817
# Epoch 81/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 0.1790 - val_accuracy: 0.9818
# Epoch 82/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.8116e-04 - accuracy: 0.9999 - val_loss: 0.1756 - val_accuracy: 0.9824
# Epoch 83/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.3277e-04 - accuracy: 0.9998 - val_loss: 0.1888 - val_accuracy: 0.9812
# Epoch 84/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.0878e-04 - accuracy: 0.9998 - val_loss: 0.1866 - val_accuracy: 0.9809
# Epoch 85/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.1007e-04 - accuracy: 0.9998 - val_loss: 0.1907 - val_accuracy: 0.9811
# Epoch 86/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.3530e-04 - accuracy: 0.9998 - val_loss: 0.1901 - val_accuracy: 0.9816
# Epoch 87/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.9736e-04 - accuracy: 0.9998 - val_loss: 0.1973 - val_accuracy: 0.9813
# Epoch 88/100
# 375/375 [==============================] - 1s 4ms/step - loss: 7.2438e-04 - accuracy: 0.9997 - val_loss: 0.1944 - val_accuracy: 0.9803
# Epoch 89/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.3417e-04 - accuracy: 0.9999 - val_loss: 0.1917 - val_accuracy: 0.9819
# Epoch 90/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.4761e-04 - accuracy: 0.9998 - val_loss: 0.1864 - val_accuracy: 0.9818
# Epoch 91/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2016 - val_accuracy: 0.9804
# Epoch 92/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.2960e-04 - accuracy: 0.9999 - val_loss: 0.1945 - val_accuracy: 0.9817
# Epoch 93/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.1946e-04 - accuracy: 0.9999 - val_loss: 0.1857 - val_accuracy: 0.9812
# Epoch 94/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.1495e-04 - accuracy: 0.9998 - val_loss: 0.1833 - val_accuracy: 0.9818
# Epoch 95/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1969 - val_accuracy: 0.9812
# Epoch 96/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.8094e-04 - accuracy: 0.9998 - val_loss: 0.2208 - val_accuracy: 0.9793
# Epoch 97/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1967 - val_accuracy: 0.9818
# Epoch 98/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.5849e-04 - accuracy: 0.9998 - val_loss: 0.2053 - val_accuracy: 0.9818
# Epoch 99/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.9503e-04 - accuracy: 0.9998 - val_loss: 0.1999 - val_accuracy: 0.9819
# Epoch 100/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.3436e-04 - accuracy: 0.9999 - val_loss: 0.1954 - val_accuracy: 0.9824
# CPU times: user 2min 33s, sys: 17.1 s, total: 2min 50s
# Wall time: 3min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.25)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1758 - accuracy: 0.9836
# Loss = 0.17577
# Accuracy = 0.98360

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
