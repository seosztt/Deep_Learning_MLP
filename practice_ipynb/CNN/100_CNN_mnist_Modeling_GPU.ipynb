# %% [markdown]
# # MNIST - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.6.0'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 35s 16ms/step - loss: 0.2763 - accuracy: 0.9141 - val_loss: 0.0753 - val_accuracy: 0.9780
# Epoch 2/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0664 - accuracy: 0.9800 - val_loss: 0.0509 - val_accuracy: 0.9858
# Epoch 3/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0428 - accuracy: 0.9868 - val_loss: 0.0444 - val_accuracy: 0.9869
# Epoch 4/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.0376 - val_accuracy: 0.9889
# Epoch 5/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.0393 - val_accuracy: 0.9887
# Epoch 6/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.0443 - val_accuracy: 0.9873
# Epoch 7/100
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0483 - val_accuracy: 0.9873
# Epoch 8/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.0399 - val_accuracy: 0.9872
# Epoch 9/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0352 - val_accuracy: 0.9909
# Epoch 10/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0377 - val_accuracy: 0.9912
# Epoch 11/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0488 - val_accuracy: 0.9893
# Epoch 12/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0455 - val_accuracy: 0.9902
# Epoch 13/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0657 - val_accuracy: 0.9882
# Epoch 14/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0490 - val_accuracy: 0.9904
# Epoch 15/100
# 375/375 [==============================] - 5s 15ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0458 - val_accuracy: 0.9923
# Epoch 16/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0613 - val_accuracy: 0.9910
# Epoch 17/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0505 - val_accuracy: 0.9918
# Epoch 18/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0504 - val_accuracy: 0.9921
# Epoch 19/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0607 - val_accuracy: 0.9908
# Epoch 20/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0572 - val_accuracy: 0.9916
# Epoch 21/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0636 - val_accuracy: 0.9909
# Epoch 22/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0672 - val_accuracy: 0.9910
# Epoch 23/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0616 - val_accuracy: 0.9923
# Epoch 24/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0785 - val_accuracy: 0.9897
# Epoch 25/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.0798 - val_accuracy: 0.9908
# Epoch 26/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0817 - val_accuracy: 0.9913
# Epoch 27/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0833 - val_accuracy: 0.9908
# Epoch 28/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0904 - val_accuracy: 0.9912
# Epoch 29/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0927 - val_accuracy: 0.9903
# Epoch 30/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0904 - val_accuracy: 0.9909
# Epoch 31/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0834 - val_accuracy: 0.9912
# Epoch 32/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0896 - val_accuracy: 0.9902
# Epoch 33/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0966 - val_accuracy: 0.9911
# Epoch 34/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0988 - val_accuracy: 0.9915
# Epoch 35/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.0971 - val_accuracy: 0.9910
# Epoch 36/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0903 - val_accuracy: 0.9918
# Epoch 37/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0954 - val_accuracy: 0.9901
# Epoch 38/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0972 - val_accuracy: 0.9909
# Epoch 39/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1018 - val_accuracy: 0.9912
# Epoch 40/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1296 - val_accuracy: 0.9902
# Epoch 41/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1105 - val_accuracy: 0.9909
# Epoch 42/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1155 - val_accuracy: 0.9916
# Epoch 43/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1075 - val_accuracy: 0.9902
# Epoch 44/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1202 - val_accuracy: 0.9908
# Epoch 45/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0994 - val_accuracy: 0.9911
# Epoch 46/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0979 - val_accuracy: 0.9911
# Epoch 47/100
# 375/375 [==============================] - 5s 13ms/step - loss: 8.6049e-04 - accuracy: 0.9998 - val_loss: 0.1164 - val_accuracy: 0.9907
# Epoch 48/100
# 375/375 [==============================] - 5s 13ms/step - loss: 3.0745e-04 - accuracy: 0.9999 - val_loss: 0.1456 - val_accuracy: 0.9895
# Epoch 49/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1165 - val_accuracy: 0.9924
# Epoch 50/100
# 375/375 [==============================] - 5s 13ms/step - loss: 5.1737e-04 - accuracy: 0.9999 - val_loss: 0.1226 - val_accuracy: 0.9914
# Epoch 51/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1393 - val_accuracy: 0.9913
# Epoch 52/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1429 - val_accuracy: 0.9906
# Epoch 53/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1655 - val_accuracy: 0.9898
# Epoch 54/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.1319 - val_accuracy: 0.9908
# Epoch 55/100
# 375/375 [==============================] - 5s 14ms/step - loss: 8.6919e-04 - accuracy: 0.9998 - val_loss: 0.1286 - val_accuracy: 0.9906
# Epoch 56/100
# 375/375 [==============================] - 5s 13ms/step - loss: 9.4828e-04 - accuracy: 0.9998 - val_loss: 0.1280 - val_accuracy: 0.9919
# Epoch 57/100
# 375/375 [==============================] - 5s 13ms/step - loss: 4.9335e-04 - accuracy: 0.9999 - val_loss: 0.1405 - val_accuracy: 0.9898
# Epoch 58/100
# 375/375 [==============================] - 5s 14ms/step - loss: 6.4730e-04 - accuracy: 0.9999 - val_loss: 0.1287 - val_accuracy: 0.9920
# Epoch 59/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1537 - val_accuracy: 0.9909
# Epoch 60/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.8632e-04 - accuracy: 0.9997 - val_loss: 0.1382 - val_accuracy: 0.9917
# Epoch 61/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.1614 - val_accuracy: 0.9897
# Epoch 62/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1370 - val_accuracy: 0.9907
# Epoch 63/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1351 - val_accuracy: 0.9919
# Epoch 64/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1369 - val_accuracy: 0.9916
# Epoch 65/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1377 - val_accuracy: 0.9916
# Epoch 66/100
# 375/375 [==============================] - 5s 13ms/step - loss: 5.8244e-04 - accuracy: 0.9999 - val_loss: 0.1593 - val_accuracy: 0.9910
# Epoch 67/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.4626e-04 - accuracy: 0.9997 - val_loss: 0.1516 - val_accuracy: 0.9911
# Epoch 68/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.1327 - val_accuracy: 0.9915
# Epoch 69/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1513 - val_accuracy: 0.9907
# Epoch 70/100
# 375/375 [==============================] - 5s 13ms/step - loss: 8.4563e-04 - accuracy: 0.9998 - val_loss: 0.1403 - val_accuracy: 0.9913
# Epoch 71/100
# 375/375 [==============================] - 5s 14ms/step - loss: 8.8869e-04 - accuracy: 0.9998 - val_loss: 0.1491 - val_accuracy: 0.9910
# Epoch 72/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1573 - val_accuracy: 0.9908
# Epoch 73/100
# 375/375 [==============================] - 5s 14ms/step - loss: 1.4301e-04 - accuracy: 0.9999 - val_loss: 0.1491 - val_accuracy: 0.9913
# Epoch 74/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1769 - val_accuracy: 0.9909
# Epoch 75/100
# 375/375 [==============================] - 5s 13ms/step - loss: 9.3069e-04 - accuracy: 0.9998 - val_loss: 0.1722 - val_accuracy: 0.9917
# Epoch 76/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1820 - val_accuracy: 0.9918
# Epoch 77/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1670 - val_accuracy: 0.9914
# Epoch 78/100
# 375/375 [==============================] - 5s 14ms/step - loss: 4.7374e-04 - accuracy: 0.9999 - val_loss: 0.1789 - val_accuracy: 0.9912
# Epoch 79/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1647 - val_accuracy: 0.9915
# Epoch 80/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1570 - val_accuracy: 0.9918
# Epoch 81/100
# 375/375 [==============================] - 5s 14ms/step - loss: 1.9698e-04 - accuracy: 0.9999 - val_loss: 0.1671 - val_accuracy: 0.9921
# Epoch 82/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1692 - val_accuracy: 0.9914
# Epoch 83/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.6618e-04 - accuracy: 0.9998 - val_loss: 0.1782 - val_accuracy: 0.9918
# Epoch 84/100
# 375/375 [==============================] - 5s 14ms/step - loss: 4.8683e-04 - accuracy: 0.9999 - val_loss: 0.1463 - val_accuracy: 0.9924
# Epoch 85/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.2001 - val_accuracy: 0.9896
# Epoch 86/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.1922e-04 - accuracy: 0.9999 - val_loss: 0.1919 - val_accuracy: 0.9912
# Epoch 87/100
# 375/375 [==============================] - 5s 13ms/step - loss: 8.2429e-04 - accuracy: 0.9998 - val_loss: 0.1989 - val_accuracy: 0.9914
# Epoch 88/100
# 375/375 [==============================] - 5s 14ms/step - loss: 8.1697e-04 - accuracy: 0.9999 - val_loss: 0.1844 - val_accuracy: 0.9921
# Epoch 89/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.1847 - val_accuracy: 0.9909
# Epoch 90/100
# 375/375 [==============================] - 5s 14ms/step - loss: 6.2764e-04 - accuracy: 0.9999 - val_loss: 0.2103 - val_accuracy: 0.9909
# Epoch 91/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1600 - val_accuracy: 0.9920
# Epoch 92/100
# 375/375 [==============================] - 5s 14ms/step - loss: 3.3971e-04 - accuracy: 0.9999 - val_loss: 0.1748 - val_accuracy: 0.9919
# Epoch 93/100
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1928 - val_accuracy: 0.9915
# Epoch 94/100
# 375/375 [==============================] - 5s 14ms/step - loss: 1.2408e-04 - accuracy: 0.9999 - val_loss: 0.1916 - val_accuracy: 0.9911
# Epoch 95/100
# 375/375 [==============================] - 5s 14ms/step - loss: 6.6376e-04 - accuracy: 0.9998 - val_loss: 0.1695 - val_accuracy: 0.9919
# Epoch 96/100
# 375/375 [==============================] - 5s 14ms/step - loss: 6.1836e-04 - accuracy: 0.9998 - val_loss: 0.1955 - val_accuracy: 0.9912
# Epoch 97/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.9299e-04 - accuracy: 0.9998 - val_loss: 0.1976 - val_accuracy: 0.9914
# Epoch 98/100
# 375/375 [==============================] - 5s 14ms/step - loss: 9.6634e-04 - accuracy: 0.9999 - val_loss: 0.1906 - val_accuracy: 0.9918
# Epoch 99/100
# 375/375 [==============================] - 5s 14ms/step - loss: 7.3470e-04 - accuracy: 0.9998 - val_loss: 0.1913 - val_accuracy: 0.9921
# Epoch 100/100
# 375/375 [==============================] - 5s 13ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.1800 - val_accuracy: 0.9913
# CPU times: user 8min 23s, sys: 34.4 s, total: 8min 58s
# Wall time: 9min 4s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
# plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1330 - accuracy: 0.9919
# Loss = 0.13302
# Accuracy = 0.99190

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
