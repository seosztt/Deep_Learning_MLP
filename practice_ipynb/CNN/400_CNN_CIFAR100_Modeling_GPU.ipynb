# %% [markdown]
# # CIFAR100 - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.5.0'

# %% [markdown]
# # I. CIFAR100 Data_Set Load

# %%
from tensorflow.keras.datasets import cifar100

(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode = 'fine')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((50000,  32, 32, 3))
X_test = X_test.reshape((10000,  32, 32, 3))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(units=256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=100, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 128)         147584
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               819456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               25700
# =================================================================
# Total params: 1,143,908
# Trainable params: 1,143,908
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 50,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 38s 28ms/step - loss: 4.2185 - accuracy: 0.0547 - val_loss: 3.7386 - val_accuracy: 0.1283
# Epoch 2/50
# 313/313 [==============================] - 8s 25ms/step - loss: 3.6448 - accuracy: 0.1372 - val_loss: 3.3561 - val_accuracy: 0.2026
# Epoch 3/50
# 313/313 [==============================] - 8s 25ms/step - loss: 3.3345 - accuracy: 0.1940 - val_loss: 3.0384 - val_accuracy: 0.2585
# Epoch 4/50
# 313/313 [==============================] - 8s 25ms/step - loss: 3.1063 - accuracy: 0.2370 - val_loss: 2.9104 - val_accuracy: 0.2845
# Epoch 5/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.9400 - accuracy: 0.2679 - val_loss: 2.7495 - val_accuracy: 0.3186
# Epoch 6/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.8020 - accuracy: 0.2964 - val_loss: 2.7204 - val_accuracy: 0.3212
# Epoch 7/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.6740 - accuracy: 0.3183 - val_loss: 2.5903 - val_accuracy: 0.3510
# Epoch 8/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.5743 - accuracy: 0.3408 - val_loss: 2.5404 - val_accuracy: 0.3557
# Epoch 9/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.4887 - accuracy: 0.3551 - val_loss: 2.5084 - val_accuracy: 0.3605
# Epoch 10/50
# 313/313 [==============================] - 8s 24ms/step - loss: 2.4147 - accuracy: 0.3715 - val_loss: 2.4681 - val_accuracy: 0.3715
# Epoch 11/50
# 313/313 [==============================] - 8s 24ms/step - loss: 2.3234 - accuracy: 0.3879 - val_loss: 2.4625 - val_accuracy: 0.3711
# Epoch 12/50
# 313/313 [==============================] - 8s 24ms/step - loss: 2.2461 - accuracy: 0.4033 - val_loss: 2.4401 - val_accuracy: 0.3775
# Epoch 13/50
# 313/313 [==============================] - 8s 24ms/step - loss: 2.1902 - accuracy: 0.4156 - val_loss: 2.4155 - val_accuracy: 0.3852
# Epoch 14/50
# 313/313 [==============================] - 8s 24ms/step - loss: 2.1190 - accuracy: 0.4293 - val_loss: 2.4106 - val_accuracy: 0.3902
# Epoch 15/50
# 313/313 [==============================] - 8s 25ms/step - loss: 2.0517 - accuracy: 0.4424 - val_loss: 2.4112 - val_accuracy: 0.3882
# Epoch 16/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.9962 - accuracy: 0.4545 - val_loss: 2.3773 - val_accuracy: 0.4023
# Epoch 17/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.9420 - accuracy: 0.4680 - val_loss: 2.3987 - val_accuracy: 0.3992
# Epoch 18/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.8896 - accuracy: 0.4746 - val_loss: 2.4162 - val_accuracy: 0.3934
# Epoch 19/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.8316 - accuracy: 0.4890 - val_loss: 2.4562 - val_accuracy: 0.3980
# Epoch 20/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.7959 - accuracy: 0.4963 - val_loss: 2.4557 - val_accuracy: 0.3948
# Epoch 21/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.7233 - accuracy: 0.5137 - val_loss: 2.5200 - val_accuracy: 0.3946
# Epoch 22/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.6953 - accuracy: 0.5203 - val_loss: 2.4684 - val_accuracy: 0.3977
# Epoch 23/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.6423 - accuracy: 0.5303 - val_loss: 2.5020 - val_accuracy: 0.4007
# Epoch 24/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.6015 - accuracy: 0.5410 - val_loss: 2.5128 - val_accuracy: 0.3981
# Epoch 25/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.5663 - accuracy: 0.5475 - val_loss: 2.5575 - val_accuracy: 0.3970
# Epoch 26/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.5243 - accuracy: 0.5591 - val_loss: 2.5378 - val_accuracy: 0.4001
# Epoch 27/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.4804 - accuracy: 0.5662 - val_loss: 2.6238 - val_accuracy: 0.3969
# Epoch 28/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.4427 - accuracy: 0.5763 - val_loss: 2.6642 - val_accuracy: 0.3918
# Epoch 29/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.3989 - accuracy: 0.5827 - val_loss: 2.7333 - val_accuracy: 0.3808
# Epoch 30/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.3686 - accuracy: 0.5930 - val_loss: 2.6833 - val_accuracy: 0.3916
# Epoch 31/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.3609 - accuracy: 0.5934 - val_loss: 2.7103 - val_accuracy: 0.3949
# Epoch 32/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.3218 - accuracy: 0.6060 - val_loss: 2.7442 - val_accuracy: 0.3975
# Epoch 33/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2884 - accuracy: 0.6094 - val_loss: 2.8248 - val_accuracy: 0.3920
# Epoch 34/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2506 - accuracy: 0.6213 - val_loss: 2.8306 - val_accuracy: 0.3908
# Epoch 35/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2254 - accuracy: 0.6271 - val_loss: 2.8581 - val_accuracy: 0.3868
# Epoch 36/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2111 - accuracy: 0.6316 - val_loss: 2.9213 - val_accuracy: 0.3886
# Epoch 37/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.1738 - accuracy: 0.6411 - val_loss: 2.9922 - val_accuracy: 0.3893
# Epoch 38/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.1597 - accuracy: 0.6413 - val_loss: 3.0046 - val_accuracy: 0.3861
# Epoch 39/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.1252 - accuracy: 0.6532 - val_loss: 3.0689 - val_accuracy: 0.3858
# Epoch 40/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.1028 - accuracy: 0.6573 - val_loss: 3.0575 - val_accuracy: 0.3826
# Epoch 41/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.0821 - accuracy: 0.6618 - val_loss: 3.1191 - val_accuracy: 0.3899
# Epoch 42/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.0741 - accuracy: 0.6655 - val_loss: 3.1479 - val_accuracy: 0.3822
# Epoch 43/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.0434 - accuracy: 0.6733 - val_loss: 3.1840 - val_accuracy: 0.3863
# Epoch 44/50
# 313/313 [==============================] - 8s 24ms/step - loss: 1.0242 - accuracy: 0.6791 - val_loss: 3.2176 - val_accuracy: 0.3873
# Epoch 45/50
# 313/313 [==============================] - 8s 25ms/step - loss: 1.0031 - accuracy: 0.6832 - val_loss: 3.2495 - val_accuracy: 0.3827
# Epoch 46/50
# 313/313 [==============================] - 8s 24ms/step - loss: 0.9841 - accuracy: 0.6891 - val_loss: 3.3056 - val_accuracy: 0.3805
# Epoch 47/50
# 313/313 [==============================] - 8s 25ms/step - loss: 0.9823 - accuracy: 0.6896 - val_loss: 3.3242 - val_accuracy: 0.3808
# Epoch 48/50
# 313/313 [==============================] - 8s 25ms/step - loss: 0.9521 - accuracy: 0.6974 - val_loss: 3.4291 - val_accuracy: 0.3803
# Epoch 49/50
# 313/313 [==============================] - 8s 25ms/step - loss: 0.9456 - accuracy: 0.6985 - val_loss: 3.4975 - val_accuracy: 0.3806
# Epoch 50/50
# 313/313 [==============================] - 8s 24ms/step - loss: 0.9273 - accuracy: 0.7040 - val_loss: 3.4222 - val_accuracy: 0.3824
# CPU times: user 5min 14s, sys: 20.1 s, total: 5min 34s
# Wall time: 7min 23s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
# plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 3.3610 - accuracy: 0.3911
# Loss = 3.36098
# Accuracy = 0.39110

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
